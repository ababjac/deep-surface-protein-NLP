# %%
# %load_ext tensorboard
# %tensorboard --logdir './models/custom-model-overlap-5_2/runs/' --port=6060
# Out:
#       <iframe id="tensorboard-frame-6dd8a61cfac8ccbd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6dd8a61cfac8ccbd");
#           const url = new URL("/", window.location);
#           const port = 6060;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
